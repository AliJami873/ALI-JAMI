# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **ALI JAMI**
#
# student

# %% [markdown]
# *I am interested in data science because it is a field that enables me to derive meaningful insights from data, which can help to make informed decisions.*

# %% [markdown]
# ### In the cell below, I will demonstrate a simple code that multiply two numbers together.

# %%
5*5
# Out:
# 25

# %% [markdown]
# ![Screenshot 2023-02-26 203442.png](attachment:31c99f02-23bf-4571-84f7-0826d3a943d7.png)

# %% [markdown]
# 1.cat
#
# 2.cow
#
# 3.sheep

# %% [markdown]
# a. list
#
# b. money
#
# c. love

# %% [markdown]
# ***
